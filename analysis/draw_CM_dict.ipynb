# %% [markdown]
# # Draw Confusion Matrix
# draw confusion martrix from saved .pt file.
# Notice: you should change the gait_cycle, sampling, and pref_path keyword first, then run all cells.

# %%
# # dict for title/res path pair 
# # running on ws3 

# with_attn_loss = {
# 	"3D CNN + Add":
# 		"/workspace/code/logs/bak/3dcnnatn_attn_map_True_add/2025-05-10/06-55-28/best_preds",
# 	"3D CNN + Mul":
# 		"/workspace/code/logs/bak/3dcnnatn_attn_map_True_mul/2025-05-10/06-55-28/best_preds",
# 	"3D CNN + Concat":	
# 		"/workspace/code/logs/bak/3dcnnatn_attn_map_True_concat/2025-05-16/13-07-01/best_preds",
# 	"3D CNN + None":
# 		"/workspace/code/logs/bak/3dcnnatn_attn_map_True_none/2025-05-16/13-07-01/best_preds",
# }

# without_attn_loss = {
# 	"3D CNN + Add":
# 		 "/workspace/code/logs/bak/3dcnn_attn_map_True_add/2025-05-10/06-55-28/best_preds"
# 	,"3D CNN + Mul":
# 		 "/workspace/code/logs/bak/3dcnn_attn_map_True_mul/2025-05-10/06-55-28/best_preds"
# 	,"3D CNN + Concat":
# 		 "/workspace/code/logs/bak/3dcnn_attn_map_True_concat/2025-05-16/13-07-01/best_preds"
# 	,"3D CNN + None":
# 		 "/workspace/code/logs/bak/3dcnn_attn_map_True_none/2025-05-16/13-07-01/best_preds"
# }

# %%
# dict for title/res path pair
# this is for LE_Lab_new results

with_attn_loss = {
	'3D CNN ATN + Add': 
		"/workspace/code/logs/3dcnnatn_attn_map_True_add/2025-05-10/11-44-02/best_preds",
	'3D CNN ATN + Mul':
		"/workspace/code/logs/3dcnnatn_attn_map_True_mul/2025-05-10/11-44-02/best_preds",
	'3D CNN ATN + Concat':
		"/workspace/code/logs/3dcnnatn_attn_map_True_concat/2025-05-10/11-44-02/best_preds",
	'3D CNN ATN + None':
		"/workspace/code/logs/3dcnnatn_attn_map_True_none/2025-05-10/11-44-02/best_preds"
}

without_attn_loss = {	
	'3D CNN + Add': 
		"/workspace/code/logs/3dcnn_attn_map_True_add/2025-05-10/11-44-02/best_preds",
	'3D CNN + Mul':
		"/workspace/code/logs/3dcnn_attn_map_True_mul/2025-05-10/11-44-02/best_preds",
	'3D CNN + Concat':
		"/workspace/code/logs/3dcnn_attn_map_True_concat/2025-05-10/11-44-02/best_preds",
	'3D CNN + None':
		"/workspace/code/logs/3dcnn_attn_map_True_none/2025-05-10/11-44-02/best_preds"
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import torch 

from torchmetrics.classification import (
MulticlassAccuracy,
MulticlassPrecision,
MulticlassRecall,
MulticlassF1Score,
MulticlassConfusionMatrix,
MulticlassAUROC,
)

# analysis with title/res path pair

def analysis_with_title_res_path_pair(pair: dict, fold: int = 5, flag: str = "with_attn_loss"):

	for title, res_path in pair.items():
		
		print('*' * 100)
		print(f"{flag}, {title}")
		all_label = []
		all_pred = []
		
		for i in range(fold):
			label = torch.load(f"{res_path}/{i}_label.pt").to(torch.int)
			pred = torch.load(f"{res_path}/{i}_pred.pt")
			all_label.append(label)
			all_pred.append(pred)

		all_label = torch.cat(all_label, dim=0)
		all_pred = torch.cat(all_pred, dim=0)
		
		print('*' * 100)
		print(title)
		confusion_matrix_data = metrics(all_pred, all_label, num_class=3)
		print('#' * 100)

		plt.rcParams.update({'font.size': 30, 'font.family': 'sans-serif'})
		axis_labels = ['ASD', 'DHS', 'LCS_HipOA']

		# draw confusion matrix
		plt.figure(figsize=(8, 6))
		sns.heatmap(confusion_matrix_data, annot=True, fmt='.2f', cmap='Reds', xticklabels=axis_labels, yticklabels=axis_labels, vmin=0, vmax=100)
		plt.title(f'{title} (%)', fontsize=30)
		plt.ylabel('Actual Label', fontsize=30)
		plt.xlabel('Predicted Label', fontsize=30)
		plt.show()
    	

def metrics(all_pred: torch.Tensor, all_label: torch.Tensor, num_class: int = 3):

	# define metrics 
	_accuracy = MulticlassAccuracy(num_class).cuda()
	_precision = MulticlassPrecision(num_class).cuda()
	_recall = MulticlassRecall(num_class).cuda()
	_f1_score = MulticlassF1Score(num_class).cuda()
	_auroc = MulticlassAUROC(num_class).cuda()
	_confusion_matrix = MulticlassConfusionMatrix(num_class, normalize="true").cuda()

	print('accuracy: %s' % _accuracy(all_pred, all_label))
	print('precision: %s' % _precision(all_pred, all_label))
	print('recall: %s' % _recall(all_pred, all_label))
	print('f1_score: %s' % _f1_score(all_pred, all_label))
	print('aurroc: %s' % _auroc(all_pred, all_label))
	print('_confusion_matrix: %s' % _confusion_matrix(all_pred, all_label))

	return _confusion_matrix(all_pred, all_label).cpu().numpy() * 100

analysis_with_title_res_path_pair(without_attn_loss, fold=10, flag="without_attn_loss")
analysis_with_title_res_path_pair(with_attn_loss, fold=10, flag="with_attn_loss")
# Out:
# ****************************************************************************************************
# without_attn_loss, 3D CNN + Add
# ****************************************************************************************************
# 3D CNN + Add
# accuracy: tensor(0.7381, device='cuda:0')
# precision: tensor(0.7658, device='cuda:0')
# recall: tensor(0.7381, device='cuda:0')
# f1_score: tensor(0.7379, device='cuda:0')
# aurroc: tensor(0.8723, device='cuda:0')
# _confusion_matrix: tensor([[0.8718, 0.0254, 0.1028],
#         [0.1758, 0.6256, 0.1986],
#         [0.2497, 0.0333, 0.7170]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# without_attn_loss, 3D CNN + Mul
# ****************************************************************************************************
# 3D CNN + Mul
# accuracy: tensor(0.6163, device='cuda:0')
# precision: tensor(0.6961, device='cuda:0')
# recall: tensor(0.6163, device='cuda:0')
# f1_score: tensor(0.6182, device='cuda:0')
# aurroc: tensor(0.8180, device='cuda:0')
# _confusion_matrix: tensor([[0.7441, 0.0304, 0.2255],
#         [0.4181, 0.4325, 0.1494],
#         [0.3200, 0.0078, 0.6722]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# without_attn_loss, 3D CNN + Concat
# ****************************************************************************************************
# 3D CNN + Concat
# accuracy: tensor(0.7275, device='cuda:0')
# precision: tensor(0.7408, device='cuda:0')
# recall: tensor(0.7275, device='cuda:0')
# f1_score: tensor(0.7226, device='cuda:0')
# aurroc: tensor(0.8671, device='cuda:0')
# _confusion_matrix: tensor([[0.8718, 0.0508, 0.0774],
#         [0.3294, 0.5664, 0.1042],
#         [0.1514, 0.1045, 0.7441]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# without_attn_loss, 3D CNN + None
# ****************************************************************************************************
# 3D CNN + None
# accuracy: tensor(0.7552, device='cuda:0')
# precision: tensor(0.7930, device='cuda:0')
# recall: tensor(0.7552, device='cuda:0')
# f1_score: tensor(0.7549, device='cuda:0')
# aurroc: tensor(0.8886, device='cuda:0')
# _confusion_matrix: tensor([[0.8976, 0.0289, 0.0735],
#         [0.2714, 0.6594, 0.0692],
#         [0.2669, 0.0244, 0.7086]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# with_attn_loss, 3D CNN ATN + Add
# ****************************************************************************************************
# 3D CNN ATN + Add
# accuracy: tensor(0.6955, device='cuda:0')
# precision: tensor(0.7019, device='cuda:0')
# recall: tensor(0.6955, device='cuda:0')
# f1_score: tensor(0.6895, device='cuda:0')
# aurroc: tensor(0.8482, device='cuda:0')
# _confusion_matrix: tensor([[0.7920, 0.1683, 0.0396],
#         [0.2374, 0.6610, 0.1017],
#         [0.2142, 0.1523, 0.6335]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# with_attn_loss, 3D CNN ATN + Mul
# ****************************************************************************************************
# 3D CNN ATN + Mul
# accuracy: tensor(0.5939, device='cuda:0')
# precision: tensor(0.7016, device='cuda:0')
# recall: tensor(0.5939, device='cuda:0')
# f1_score: tensor(0.5835, device='cuda:0')
# aurroc: tensor(0.7752, device='cuda:0')
# _confusion_matrix: tensor([[0.8792, 0.0106, 0.1102],
#         [0.4147, 0.5300, 0.0554],
#         [0.6063, 0.0210, 0.3727]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# with_attn_loss, 3D CNN ATN + Concat
# ****************************************************************************************************
# 3D CNN ATN + Concat
# accuracy: tensor(0.6984, device='cuda:0')
# precision: tensor(0.7316, device='cuda:0')
# recall: tensor(0.6984, device='cuda:0')
# f1_score: tensor(0.6942, device='cuda:0')
# aurroc: tensor(0.8586, device='cuda:0')
# _confusion_matrix: tensor([[0.8635, 0.0636, 0.0729],
#         [0.2841, 0.6223, 0.0936],
#         [0.3328, 0.0576, 0.6095]], device='cuda:0')
# ####################################################################################################
# ****************************************************************************************************
# with_attn_loss, 3D CNN ATN + None
# ****************************************************************************************************
# 3D CNN ATN + None
# accuracy: tensor(0.7485, device='cuda:0')
# precision: tensor(0.7767, device='cuda:0')
# recall: tensor(0.7485, device='cuda:0')
# f1_score: tensor(0.7453, device='cuda:0')
# aurroc: tensor(0.8826, device='cuda:0')
# _confusion_matrix: tensor([[0.9039, 0.0524, 0.0437],
#         [0.2958, 0.6205, 0.0838],
#         [0.2287, 0.0502, 0.7211]], device='cuda:0')
# ####################################################################################################
